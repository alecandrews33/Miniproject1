# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt('training_data.txt', skiprows=1)
X = data[:, 1:]
y = data[:, 0]

file = open('training_data.txt', 'r')
line = file.readline()
words = line.split(" ")[1:]

# %%
words.index("")
# Out:
# 'L'

# %%
revised = ["like", "great", "good", "love", "best", "want", "ever", "recommend", "enjoy", "never", "bad", "need",
          "disappoint", "money", "wast", "doesnt", "bore", "help", "problem", "excel", "anyon", "price", "hard",
          "right", "hope", "nice", "fun", "without", "big", "favorit", "quit", "worst", "beauti", "amaz", "poor",
          "true", "pleas", "perfect", "wish", "funni", "style", "size", "wont", "less", "wasnt", "least", "kind", 
          "stop", "perform", "terribl", "absolut", "especi", "happi", "fine", "horribl", "replac", "rather", "awesom",
          "thank", "american", "simpli", "excit", "truli", "ok", "extrem", "hate", "god", "design", "difficult", "issu",
          "die", "easili", "unfortun", "impress", "cool", "extra", "hot", "stupid", "incred", "fantast", "valu", "break",
          "cost", "glad", "pop", "kill", "greatest", "fail", "sad", "sorri", "horror", "annoy", "suck", "comfort", 
          "clean", "wors", "leak", "quickli", "poorli", "inspir", "death", "expens", "mistak", "dead", "weak", "junk",
          "wow", "avoid", "okay", "none", "brilliant", "troubl", "improv", "cute", "lose", "doubt", "crap", "correct",
          "fascin", "success", "frustrat", "satisfi", "creativ", "perfectli", "uniqu", "trash", "bewar", "useless", "hell",
          "rare", "imposs", "broken", "mess", "ridicul", "prefer", "ruin", "dissapoint", "delight", "refund", "complaint"]

# %%
important_words = []
for i in range(len(revised)):
    important_words.append(words.index("%s" % revised[i]))

# %%
important_words
# Out:
# [6,
#  7,
#  8,
#  14,
#  30,
#  31,
#  56,
#  58,
#  59,
#  60,
#  62,
#  72,
#  76,
#  77,
#  110,
#  112,
#  118,
#  119,
#  128,
#  129,
#  130,
#  138,
#  142,
#  144,
#  145,
#  147,
#  148,
#  149,
#  155,
#  160,
#  170,
#  182,
#  183,
#  195,
#  210,
#  214,
#  220,
#  226,
#  236,
#  242,
#  245,
#  246,
#  249,
#  252,
#  258,
#  263,
#  266,
#  280,
#  281,
#  283,
#  284,
#  297,
#  298,
#  301,
#  302,
#  305,
#  321,
#  323,
#  330,
#  333,
#  334,
#  336,
#  344,
#  362,
#  367,
#  371,
#  411,
#  427,
#  429,
#  438,
#  443,
#  444,
#  451,
#  455,
#  469,
#  470,
#  476,
#  486,
#  496,
#  503,
#  506,
#  510,
#  515,
#  517,
#  518,
#  519,
#  520,
#  529,
#  538,
#  541,
#  546,
#  592,
#  562,
#  576,
#  565,
#  584,
#  610,
#  615,
#  646,
#  647,
#  651,
#  674,
#  706,
#  710,
#  720,
#  721,
#  730,
#  732,
#  736,
#  742,
#  773,
#  787,
#  796,
#  801,
#  804,
#  805,
#  808,
#  811,
#  815,
#  829,
#  831,
#  841,
#  845,
#  864,
#  878,
#  879,
#  882,
#  884,
#  902,
#  917,
#  919,
#  921,
#  929,
#  934,
#  935,
#  973,
#  967,
#  956,
#  965,
#  994]

# %%
for point in X:
    for i in range(len(point)):
        point[i] /= 22

# %%
print(X.shape)
# Out:
# (20000, 1000)

# %%
x_train = X[:19001]
y_train = y[:19001]
x_test = X[19001:]
y_test = y[19001:]

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import Flatten, BatchNormalization
from keras import regularizers

model = Sequential()
model.add(Dense(300, input_dim = 1000))
model.add(Activation('sigmoid'))
model.add(Dense(200))
model.add(Activation('softplus'))
model.add(Dropout(0.20))
model.add(Dense(120))
model.add(Activation('relu'))
model.add(Dense(90))
model.add(Activation('softplus'))
model.add(Dropout(0.10))
model.add(Dense(60))
model.add(Activation('selu'))
model.add(Dense(20))
model.add(Activation('softplus'))
model.add(Dense(1))
model.add(Activation('softplus'))

model.summary()

model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])

fit = model.fit(np.array(X), np.array(y), batch_size=128, epochs=25,
    verbose=1)

score = model.evaluate(np.array(x_test), np.array(y_test), verbose=0)
print('Testing score:', score[0])
print('Testing accuracy:', score[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_368 (Dense)            (None, 300)               300300
# _________________________________________________________________
# activation_369 (Activation)  (None, 300)               0
# _________________________________________________________________
# dense_369 (Dense)            (None, 200)               60200
# _________________________________________________________________
# activation_370 (Activation)  (None, 200)               0
# _________________________________________________________________
# dropout_106 (Dropout)        (None, 200)               0
# _________________________________________________________________
# dense_370 (Dense)            (None, 120)               24120
# _________________________________________________________________
# activation_371 (Activation)  (None, 120)               0
# _________________________________________________________________
# dense_371 (Dense)            (None, 90)                10890
# _________________________________________________________________
# activation_372 (Activation)  (None, 90)                0
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 90)                0
# _________________________________________________________________
# dense_372 (Dense)            (None, 60)                5460
# _________________________________________________________________
# activation_373 (Activation)  (None, 60)                0
# _________________________________________________________________
# dense_373 (Dense)            (None, 20)                1220
# _________________________________________________________________
# activation_374 (Activation)  (None, 20)                0
# _________________________________________________________________
# dense_374 (Dense)            (None, 1)                 21
# _________________________________________________________________
# activation_375 (Activation)  (None, 1)                 0
# =================================================================
# Total params: 402,211
# Trainable params: 402,211
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 20000/20000 [==============================] - 7s 339us/step - loss: 0.7181 - acc: 0.4969
# Epoch 2/25
# 20000/20000 [==============================] - 3s 135us/step - loss: 0.6954 - acc: 0.5005
# Epoch 3/25
# 20000/20000 [==============================] - 3s 138us/step - loss: 0.6939 - acc: 0.5070
# Epoch 4/25
# 20000/20000 [==============================] - 3s 139us/step - loss: 0.6784 - acc: 0.5616
# Epoch 5/25
# 20000/20000 [==============================] - 3s 141us/step - loss: 0.6279 - acc: 0.6699
# Epoch 6/25
# 20000/20000 [==============================] - 3s 143us/step - loss: 0.7758 - acc: 0.6076
# Epoch 7/25
# 20000/20000 [==============================] - 3s 144us/step - loss: 0.5674 - acc: 0.7218
# Epoch 8/25
# 20000/20000 [==============================] - 3s 146us/step - loss: 0.5409 - acc: 0.7461
# Epoch 9/25
# 20000/20000 [==============================] - 3s 147us/step - loss: 0.4576 - acc: 0.8088
# Epoch 10/25
# 20000/20000 [==============================] - 3s 157us/step - loss: 0.4073 - acc: 0.8266
# Epoch 11/25
# 20000/20000 [==============================] - 3s 139us/step - loss: 0.3954 - acc: 0.8355
# Epoch 12/25
# 20000/20000 [==============================] - 3s 140us/step - loss: 0.3909 - acc: 0.8424
# Epoch 13/25
# 20000/20000 [==============================] - 3s 138us/step - loss: 0.3828 - acc: 0.8396
# Epoch 14/25
# 20000/20000 [==============================] - 3s 139us/step - loss: 0.4406 - acc: 0.8175
# Epoch 15/25
# 20000/20000 [==============================] - 3s 145us/step - loss: 0.4273 - acc: 0.8126
# Epoch 16/25
# 20000/20000 [==============================] - 3s 146us/step - loss: 0.4164 - acc: 0.8296
# Epoch 17/25
# 20000/20000 [==============================] - 3s 149us/step - loss: 0.3982 - acc: 0.8511
# Epoch 18/25
# 20000/20000 [==============================] - 3s 151us/step - loss: 0.3757 - acc: 0.8455
# Epoch 19/25
#  - ETA: 2s - loss: 0.3817 - acc: 0.8414
# Epoch 20/25
# 20000/20000 [==============================] - 3s 154us/step - loss: 0.3496 - acc: 0.8602
# Epoch 21/25
# 20000/20000 [==============================] - 3s 174us/step - loss: 0.3455 - acc: 0.8599
# Epoch 22/25
# 20000/20000 [==============================] - 3s 147us/step - loss: 0.3445 - acc: 0.8637
# Epoch 23/25
# 20000/20000 [==============================] - 3s 151us/step - loss: 0.3720 - acc: 0.8556
# Epoch 24/25
# 20000/20000 [==============================] - 3s 150us/step - loss: 0.3438 - acc: 0.8669
# Epoch 25/25
# 20000/20000 [==============================] - 3s 151us/step - loss: 0.3517 - acc: 0.8651
# Testing score: 0.31462621784305667
# Testing accuracy: 0.8778778778778779

# %%
test = np.loadtxt('test_data.txt', skiprows=1)
testY = model.predict(test)

# %%
f = open('neuralNet.txt','w')
f.write('Id,Prediction\n')
id = 1

for i in range(len(test)):
    
    f.write(str(id) + ',' + str(int(testY[i])) + '\n')
    id += 1
